# %%
from PIL import Image
from nerofs import NEROFS

nerofs = NEROFS("")

image1 = nerofs.open("surprised_pika.jpg","rb")
# L'image doit être enregistrée à la racine du dossier "Mes Documents" de l'ENT 
img1 = Image.open(image1)

#Exécuter cette cellule

# %%
img1
#Exécuter pour vérifier que la première image s'affiche correctement

# %%
image2 = nerofs.open("paysage.jpg","rb")
img2 = Image.open(image2)
#Exécuter pour charger la deuxième image

# %%
img2
#Exécuter pour vérifier que la deuxième image s'affiche correctement

# %%
img3 = Image.new("RGB",(...,...))
#Compléter les dimensions nécessaires pour cette troisième image,
#en remplaçant les pointillés par les bonnes valeurs, puis exécuter cette cellule.

# %%
#Compléter le programme ci-dessous pour insérer Pikachu dans le décor.

for i in range(...):
    for j in range(...):
        couleur = img1.getpixel((0,0))  #On récupère la valeur du premier pixel de 
                                        #la première ligne de l'image avec Pikachu
        p1 = img1.getpixel((...,...))
        p2 = img2.getpixel((...,...))
        if p1 == ...:
            img3.putpixel((...,...),...)
        else:
            img3.putpixel((...,...),...)

#Exécuter cette cellule une fois qu'elle est complétée

# %%
img3
#A exécuter pour vérifier que la fusion d'images s'est bien effectuée
